# %% [markdown]
# <a href="https://colab.research.google.com/github/riyaa321/FakeNewsDetection/blob/main/FakeNewsDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
true=pd.read_csv('True.csv')

# %%
fake=pd.read_csv('Fake.csv')

# %%
true.head
# Out:
# <bound method NDFrame.head of                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]>

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
fake['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news=pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news=news.sample(frac=1)

# %%
news.head()
# Out:
#                                                    title  \
# 824    Manafort pledges $12 million in assets in bid ...
# 14541  More work to be done to unlock Brexit talks: B...
# 18173  Keeping the competition out: Iran startups thr...
# 14502  JUST ONE DISGRACEFUL PHOTO Captures The Essenc...
# 20079  Myanmar’s Suu Kyi working to get aid to Rohing...
#
#                                                     text       subject  \
# 824    WASHINGTON (Reuters) - President Donald Trump’...  politicsNews
# 14541  GOTHENBURG, Sweden (Reuters) - British Prime M...     worldnews
# 18173  LONDON (Reuters) - Low on cash but high on hop...     worldnews
# 14502   Social media went crazy last night when a pho...      politics
# 20079  WASHINGTON (Reuters) - U.S. Senate Majority Le...     worldnews
#
#                       date  label
# 824      November 4, 2017       1
# 14541   November 17, 2017       1
# 18173     October 6, 2017       1
# 14502         Feb 10, 2016      0
# 20079  September 14, 2017       1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                              title  \
# 0    824  Manafort pledges $12 million in assets in bid ...
# 1  14541  More work to be done to unlock Brexit talks: B...
# 2  18173  Keeping the competition out: Iran startups thr...
# 3  14502  JUST ONE DISGRACEFUL PHOTO Captures The Essenc...
# 4  20079  Myanmar’s Suu Kyi working to get aid to Rohing...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - President Donald Trump’...  politicsNews
# 1  GOTHENBURG, Sweden (Reuters) - British Prime M...     worldnews
# 2  LONDON (Reuters) - Low on cash but high on hop...     worldnews
# 3   Social media went crazy last night when a pho...      politics
# 4  WASHINGTON (Reuters) - U.S. Senate Majority Le...     worldnews
#
#                   date  label
# 0    November 4, 2017       1
# 1   November 17, 2017       1
# 2     October 6, 2017       1
# 3         Feb 10, 2016      0
# 4  September 14, 2017       1

# %%
news.drop('index',axis=1,inplace=True)

# %%
news.head()
# Out:
#                                                title  \
# 0  Manafort pledges $12 million in assets in bid ...
# 1  More work to be done to unlock Brexit talks: B...
# 2  Keeping the competition out: Iran startups thr...
# 3  JUST ONE DISGRACEFUL PHOTO Captures The Essenc...
# 4  Myanmar’s Suu Kyi working to get aid to Rohing...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - President Donald Trump’...  politicsNews
# 1  GOTHENBURG, Sweden (Reuters) - British Prime M...     worldnews
# 2  LONDON (Reuters) - Low on cash but high on hop...     worldnews
# 3   Social media went crazy last night when a pho...      politics
# 4  WASHINGTON (Reuters) - U.S. Senate Majority Le...     worldnews
#
#                   date  label
# 0    November 4, 2017       1
# 1   November 17, 2017       1
# 2     October 6, 2017       1
# 3         Feb 10, 2016      0
# 4  September 14, 2017       1

# %%
news.tail()
# Out:
#                                                    title  \
# 44893  WATCH: TRUMP STAYS ABOVE FRAY In Flint After D...
# 44894   Hillary Responds To Trump’s London Failure An...
# 44895  Trump would want Moore to step aside if sexual...
# 44896   Log Cabin Republicans Finally Grow A Pair Whe...
# 44897  UN AMBASSADOR SAMANTHA POWER Unmasked Hundreds...
#
#                                                     text       subject  \
# 44893  Even the Democrat ministers can t help themsel...     left-news
# 44894  Donald Trump s reaction to the London terroris...          News
# 44895  DANANG, Vietnam (Reuters) - U.S. President Don...  politicsNews
# 44896  The idea of there being a group of people who ...          News
# 44897  Adam Kredo of WFB asks the question we all wan...      politics
#
#                      date  label
# 44893        Sep 15, 2016      0
# 44894        June 5, 2017      0
# 44895  November 10, 2017       1
# 44896    October 23, 2016      0
# 44897         Aug 5, 2017      0

# %%
import re

# %%
def wordopt(text):
    # Convert into lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d+', '', text)

    # Remove newline characters
    text = re.sub(r'\n', ' ', text)

    return text

# %%
news['text']=news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        washington reuters  president donald trumps fo...
# 1        gothenburg sweden reuters  british prime minis...
# 2        london reuters  low on cash but high on hope i...
# 3         social media went crazy last night when a pho...
# 4        washington reuters  us senate majority leader ...
#                                ...
# 44893    even the democrat ministers can t help themsel...
# 44894    donald trump s reaction to the london terroris...
# 44895    danang vietnam reuters  us president donald tr...
# 44896    the idea of there being a group of people who ...
# 44897    adam kredo of wfb asks the question we all wan...
# Name: text, Length: 44898, dtype: object

# %%
x=news['text']
y=news['label']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization=TfidfVectorizer()

# %%
xv_train=vectorization.fit_transform(x_train)

# %%
xv_test=vectorization.transform(x_test)

# %%
xv_train.shape
# Out:
# (31428, 174430)

# %%
xv_test.shape
# Out:
# (13470, 174430)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
xv_test.shape
# Out:
# (13470, 174430)

# %%
xv_test.shape
# Out:
# (13470, 174430)

# %%
xv_train.shape
# Out:
# (31428, 174430)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9899034892353378

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7073
#            1       0.99      0.99      0.99      6397
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC= DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc= DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)
# Out:
# 0.9970304380103935

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7073
#            1       1.00      1.00      1.00      6397
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(xv_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc=rfc.predict(xv_test)

# %%
rfc.score(xv_test,y_test)
# Out:
# 0.9882702301410542

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7073
#            1       0.99      0.99      0.99      6397
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc= GradientBoostingClassifier()

# %%
gbc.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc=gbc.predict(xv_test)

# %%
gbc.score (xv_test,y_test)
# Out:
# 0.9961395694135116

# %%
print(classification_report(y_test,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7073
#            1       0.99      1.00      1.00      6397
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
def output_label(n):
    if n == 0:
        return "It is a Fake News"
    elif n == 1:
        return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_lr = LR.predict(new_xv_test)

    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)

    return "\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_lr[0]), output_label(pred_gbc[0]), output_label(pred_rfc[0])
    )

# %%
news_article=str(input())
# Out:
# http://unreliable-source.info/celebrity-scandal/breaking-news

# %%
manual_testing(news_article)
# Out:
# '\n\nLR Prediction: It is a Fake News \nGBC Prediction: It is a Fake News \nRFC Prediction: It is a Fake News'
